# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import cv2
from torch.utils.data import DataLoader, Dataset
import numpy as np
import os
import torchvision.transforms as transforms
import pandas as pd

# %%
class VideoDataset(Dataset):
    def __init__(self, csv_file, root_dir,output_folder):
        self.csv_file = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.file_suffix = '.avi'
        self.video_files = os.listdir(self.root_dir)
        # 读取 root_dir 下的所有视频文件，获取他们的文件名
        self.video_files_name = [i.split('.')[0] for i in self.video_files]
        # 将获得的文件名到 csv 文件中查找对应的标签，csv 文件中的 FileName 是文件名，health 是标签
        self.labels = []
        self.video_useful_name = []
        for i in self.video_files_name:
            self.labels.append(self.csv_file.loc[self.csv_file['FileName'] == i, ' health'].values[0])
            self.video_useful_name.append(i)
        #将self.video_useful_name里面所有的文件都添加上.avi后缀
        self.video_files = [i + self.file_suffix for i in self.video_useful_name]
        self.labels = np.array(self.labels)
        self.output_folder = output_folder
    
    def get_frames(self):
        frames = []
        # 遍历所有视频文件
        for video_file in self.video_files:
            video_path = os.path.join(self.root_dir, video_file)
            video_output_dir = os.path.join(self.output_folder, video_file.split('.')[0])
            cap = cv2.VideoCapture(video_path)
            frame_count = 0
            extracted_frames = []
            ventricular_sizes = []
            while cap.isOpened():
            # 获取视频的第一帧和第二帧，以及视频的宽和高
                ret, frame = cap.read()
                if not ret:
                    break
                frame_path = os.path.join(video_output_dir, f'frame_{frame_count:04d}.png')
                cv2.imwrite(frame_path, frame)
                extracted_frames.append(frame)

                gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

                blurred = cv2.GaussianBlur(gray, (5, 5), 0)

                _, thresh = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

                contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

                largest_contour = max(contours, key=cv2.contourArea) if contours else None

                if largest_contour is not None:
                    ventricular_area = cv2.contourArea(largest_contour)
                else:
                    ventricular_area = 0

                ventricular_sizes.append(ventricular_area)
                frame_count += 1
            cap.release()   
            diastole_frame_index = np.argmax(ventricular_sizes)
            systole_frame_index = np.argmin(ventricular_sizes)
            # print(diastole_frame_index)
            # print(systole_frame_index)
            # # 将 frame1 和 frame2 合并成一个两通道的图片，他们本身就是灰度图
            # print(extracted_frames[diastole_frame_index].shape)
            # print(extracted_frames[systole_frame_index].shape)
            frame = np.concatenate([extracted_frames[diastole_frame_index],extracted_frames[systole_frame_index]], axis=2)
            frame = frame.transpose(2, 0, 1)
            frames.append(frame)
        frames = torch.tensor(frames)
        labels = torch.tensor(self.labels).float()
        print(frames.shape)
        print(labels)
        return frames, labels
testdataset = VideoDataset('/home/curry/code/curry_code_summay/AI/for_dc/FileList_new.csv', '/home/curry/code/视频划分/TEST','/home/curry/code/视频划分/output_folder')
test_frames,test_labels = testdataset.get_frames()
traindataset = VideoDataset('/home/curry/code/curry_code_summay/AI/for_dc/FileList_new.csv', '/home/curry/code/视频划分/TRAIN','/home/curry/code/视频划分/output_folder')
train_frames,train_labels = traindataset.get_frames()
valdataset = VideoDataset('/home/curry/code/curry_code_summay/AI/for_dc/FileList_new.csv', '/home/curry/code/视频划分/VAL','/home/curry/code/视频划分/output_folder')
val_frames,val_labels = valdataset.get_frames()

#将他们转换成 pytorch 的 tensor，作为神经网络的输入
# frames = torch.tensor(frames)
# labels = torch.tensor(labels)
# Out:
# /tmp/ipykernel_16336/1164004502.py:67: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   frames = torch.tensor(frames)
# torch.Size([1277, 6, 112, 112])
# tensor([1., 1., 0.,  ..., 0., 1., 0.])
# torch.Size([7464, 6, 112, 112])
# tensor([1., 1., 0.,  ..., 0., 0., 1.])
# torch.Size([1288, 6, 112, 112])
# tensor([1., 1., 1.,  ..., 1., 1., 1.])

# %%
from torch.utils.data import TensorDataset
#对trainframe进行数据增强,对testframe不进行数据增强
# train_transforms = transforms.Compose([
#     transforms.RandomHorizontalFlip(),
#     transforms.RandomVerticalFlip(),
#     transforms.RandomRotation(30),
# ])
# train_frames = train_transforms(train_frames)

# 创建 TensorDataset
train_dataset = TensorDataset(train_frames, train_labels)
test_dataset = TensorDataset(test_frames, test_labels)
val_dataset = TensorDataset(val_frames, val_labels)

# 创建 DataLoader
batch_size = 32  # 你可以根据需要调整批次大小
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# 检查 DataLoader 中的数据
for i, (inputs, labels) in enumerate(train_loader):
    print(f"Batch {i}: inputs shape = {inputs.shape}, labels shape = {labels.shape}")
    break  # 仅检查第一个批次
# Out:
# Batch 0: inputs shape = torch.Size([32, 6, 112, 112]), labels shape = torch.Size([32])

# %%
#定义残差块
class ResidualBlock(nn.Module):
    def __init__(self, inchannel, outchannel, stride=1):
        super(ResidualBlock, self).__init__()
        self.left = nn.Sequential(
            nn.Conv2d(inchannel, outchannel, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(outchannel),
            nn.ReLU(inplace=True),
            nn.Conv2d(outchannel, outchannel, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(outchannel)
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or inchannel != outchannel:
            self.shortcut = nn.Sequential(
                nn.Conv2d(inchannel, outchannel, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(outchannel)
            )
    def forward(self, x):
        out = self.left(x)
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
#定义ResNet18模型
class ResNet(nn.Module):
    def __init__(self, ResidualBlock, num_classes=1000):
        super(ResNet, self).__init__()
        self.inchannel = 64
        self.conv1 = nn.Sequential(
            nn.Conv2d(6, 64, kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        self.layer1 = self.make_layer(ResidualBlock, 64, 2, stride=1)
        self.layer2 = self.make_layer(ResidualBlock, 128, 2, stride=2)
        self.layer3 = self.make_layer(ResidualBlock, 256, 2, stride=2)
        self.layer4 = self.make_layer(ResidualBlock, 512, 2, stride=2)
        self.dropout = nn.Dropout(0.3)
        self.fc = nn.Linear(25088, num_classes)
    def make_layer(self, block, channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.inchannel, channels, stride))
            self.inchannel = channels
        return nn.Sequential(*layers)
    def forward(self, x):
        out = self.conv1(x)
        #print(out.shape)
        out = self.layer1(out)
        #print(out.shape)
        out = self.layer2(out)
        #print(out.shape)
        out = self.layer3(out)
        #print(out.shape)
        out = self.layer4(out)
        #print(out.shape)
        out = F.avg_pool2d(out, 1)
        #print(out.shape)
        out = out.view(out.size(0), -1)
        # if self.training:
        #     out = self.dropout(out)
        #print(out.shape)
        out = self.fc(out)
        return out

# %%
import time
from sklearn.metrics import roc_auc_score,f1_score,mean_absolute_error
# 实例化模型
model = ResNet(ResidualBlock, 2)  # ResNet18
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# 定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# 训练模型
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        inputs = inputs.float()
        labels = labels.long()
        # 前向传播
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    

    #评估模型
    model.eval()
    all_probabilities = []
    all_labels = []
    all_predictions = []
    all_outputs = []
    correct = 0
    total = 0
    time_start = time.time()
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            inputs = inputs.float()
            labels = labels.long()
            outputs = model(inputs)
            # 计算 AUC
            probabilities = torch.softmax(outputs, dim=1)[:, 1].cpu().detach().numpy()
            all_probabilities.extend(probabilities)
            all_labels.extend(labels.cpu().detach().numpy())
            
            # 计算 Dice 相似系数
            predictions = torch.argmax(outputs, dim=1).cpu().detach().numpy()
            all_predictions.extend(predictions)
            
            # 计算 MAE
            all_outputs.extend(outputs.cpu().detach().numpy())
            
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    time_end = time.time()
    print(f"Time cost: {(time_end - time_start)/1277}ms")
    print(f"Accuracy of the model on the test images: {100 * correct / total:.2f}%")


    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_loader):.4f}")
    # 转换为 numpy 数组
    all_labels = np.array(all_labels)
    all_probabilities = np.array(all_probabilities)
    all_predictions = np.array(all_predictions)
    all_outputs = np.array(all_outputs)

    # 计算 AUC
    auc = roc_auc_score(all_labels, all_probabilities)
    print(f"AUC: {auc:.4f}")

    # 计算 Dice 相似系数
    dice = f1_score(all_labels, all_predictions, average='binary')
    print(f"Dice Similarity Coefficient: {dice:.4f}")

    # 计算 MAE
    # mae = mean_absolute_error(all_labels, all_outputs)
    # print(f"Mean Absolute Error: {mae:.4f}")

# 评估模型
# model.eval()
# correct = 0
# total = 0
# time_start = time.time()
# with torch.no_grad():
#     for inputs, labels in test_loader:
#         inputs, labels = inputs.to(device), labels.to(device)
#         inputs = inputs.float()
#         labels = labels.long()
#         outputs = model(inputs)
#         _, predicted = torch.max(outputs.data, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()

# time_end = time.time()
# print(f"Time cost: {time_end - time_start:.2f}s")
# print(f"Accuracy of the model on the test images: {100 * correct / total:.2f}%")
# Out:
# Time cost: 0.00022635575655203082ms
# Accuracy of the model on the test images: 78.49%
# Epoch [1/100], Loss: 0.9102
# AUC: 0.6781
# Dice Similarity Coefficient: 0.8748
# Time cost: 0.00022739438032301124ms
# Accuracy of the model on the test images: 79.58%
# Epoch [2/100], Loss: 0.6120
# AUC: 0.7244
# Dice Similarity Coefficient: 0.8803
# Time cost: 0.00022298148953550574ms
# Accuracy of the model on the test images: 78.18%
# Epoch [3/100], Loss: 0.4983
# AUC: 0.7395
# Dice Similarity Coefficient: 0.8651
# Time cost: 0.00022178211525817728ms
# Accuracy of the model on the test images: 80.67%
# Epoch [4/100], Loss: 0.4712
# AUC: 0.7428
# Dice Similarity Coefficient: 0.8872
# Time cost: 0.0002368459873304016ms
# Accuracy of the model on the test images: 80.98%
# Epoch [5/100], Loss: 0.4526
# AUC: 0.7525
# Dice Similarity Coefficient: 0.8873
# Time cost: 0.0002222208651883955ms
# Accuracy of the model on the test images: 80.51%
# Epoch [6/100], Loss: 0.4345
# AUC: 0.7608
# Dice Similarity Coefficient: 0.8841
# Time cost: 0.0002193734714923282ms
# Accuracy of the model on the test images: 80.59%
# Epoch [7/100], Loss: 0.4297
# AUC: 0.7634
# Dice Similarity Coefficient: 0.8840
# Time cost: 0.00021712539153072923ms
# Accuracy of the model on the test images: 80.59%
# Epoch [8/100], Loss: 0.4076
# AUC: 0.7792
# Dice Similarity Coefficient: 0.8777
# Time cost: 0.00021791943555337523ms
# Accuracy of the model on the test images: 81.29%
# Epoch [9/100], Loss: 0.3873
# AUC: 0.7757
# Dice Similarity Coefficient: 0.8846
# Time cost: 0.0002163897852647463ms
# Accuracy of the model on the test images: 79.81%
# Epoch [10/100], Loss: 0.3729
# AUC: 0.7504
# Dice Similarity Coefficient: 0.8730
# Time cost: 0.00021732871011541333ms
# Accuracy of the model on the test images: 81.60%
# Epoch [11/100], Loss: 0.3556
# AUC: 0.7733
# Dice Similarity Coefficient: 0.8907
# Time cost: 0.00021394585480238184ms
# Accuracy of the model on the test images: 78.42%
# Epoch [12/100], Loss: 0.3324
# AUC: 0.7680
# Dice Similarity Coefficient: 0.8613
# Time cost: 0.00021743699733223313ms
# Accuracy of the model on the test images: 79.11%
# Epoch [13/100], Loss: 0.3048
# AUC: 0.7794
# Dice Similarity Coefficient: 0.8656
# Time cost: 0.00021574192898480708ms
# Accuracy of the model on the test images: 81.83%
# Epoch [14/100], Loss: 0.2666
# AUC: 0.7735
# Dice Similarity Coefficient: 0.8924
# Time cost: 0.00021666330383826533ms
# Accuracy of the model on the test images: 78.57%
# Epoch [15/100], Loss: 0.2280
# AUC: 0.7571
# Dice Similarity Coefficient: 0.8644
# Time cost: 0.00021628000443114277ms
# Accuracy of the model on the test images: 82.53%
# Epoch [16/100], Loss: 0.1921
# AUC: 0.7715
# Dice Similarity Coefficient: 0.8943
# Time cost: 0.00023354490753627887ms
# Accuracy of the model on the test images: 77.25%
# Epoch [17/100], Loss: 0.1521
# AUC: 0.7547
# Dice Similarity Coefficient: 0.8539
# Time cost: 0.00021615472732340813ms
# Accuracy of the model on the test images: 77.95%
# Epoch [18/100], Loss: 0.1077
# AUC: 0.7586
# Dice Similarity Coefficient: 0.8581
# Time cost: 0.0002170342809069222ms
# Accuracy of the model on the test images: 79.11%
# Epoch [19/100], Loss: 0.0866
# AUC: 0.7734
# Dice Similarity Coefficient: 0.8660
# Time cost: 0.0002150261131412085ms
# Accuracy of the model on the test images: 77.64%
# Epoch [20/100], Loss: 0.0736
# AUC: 0.7568
# Dice Similarity Coefficient: 0.8574
# Time cost: 0.00021492062645585814ms
# Accuracy of the model on the test images: 76.71%
# Epoch [21/100], Loss: 0.0700
# AUC: 0.7298
# Dice Similarity Coefficient: 0.8519
# Time cost: 0.00021434745101510497ms
# Accuracy of the model on the test images: 78.49%
# Epoch [22/100], Loss: 0.0620
# AUC: 0.7606
# Dice Similarity Coefficient: 0.8652
# Time cost: 0.0002163464703780184ms
# Accuracy of the model on the test images: 79.43%
# Epoch [23/100], Loss: 0.0621
# AUC: 0.7539
# Dice Similarity Coefficient: 0.8709
# Time cost: 0.00021587728800583184ms
# Accuracy of the model on the test images: 77.95%
# Epoch [24/100], Loss: 0.0388
# AUC: 0.7446
# Dice Similarity Coefficient: 0.8595
# Time cost: 0.00022644836079262155ms
# Accuracy of the model on the test images: 79.43%
# Epoch [25/100], Loss: 0.0596
# AUC: 0.7659
# Dice Similarity Coefficient: 0.8712
# Time cost: 0.00021571672420158178ms
# Accuracy of the model on the test images: 79.43%
# Epoch [26/100], Loss: 0.0231
# AUC: 0.7573
# Dice Similarity Coefficient: 0.8690
# Time cost: 0.00021520385353847137ms
# Accuracy of the model on the test images: 80.98%
# Epoch [27/100], Loss: 0.0229
# AUC: 0.7685
# Dice Similarity Coefficient: 0.8841
# Time cost: 0.00021561030400574162ms
# Accuracy of the model on the test images: 78.88%
# Epoch [28/100], Loss: 0.0255
# AUC: 0.7470
# Dice Similarity Coefficient: 0.8683
# Time cost: 0.00021605502840309473ms
# Accuracy of the model on the test images: 77.17%
# Epoch [29/100], Loss: 0.0348
# AUC: 0.7688
# Dice Similarity Coefficient: 0.8495
# Time cost: 0.0002166872017068049ms
# Accuracy of the model on the test images: 78.73%
# Epoch [30/100], Loss: 0.0448
# AUC: 0.7697
# Dice Similarity Coefficient: 0.8646
# Time cost: 0.0002169489580481521ms
# Accuracy of the model on the test images: 76.63%
# Epoch [31/100], Loss: 0.0324
# AUC: 0.7719
# Dice Similarity Coefficient: 0.8470
# Time cost: 0.00022802057915958653ms
# Accuracy of the model on the test images: 78.34%
# Epoch [32/100], Loss: 0.0403
# AUC: 0.7624
# Dice Similarity Coefficient: 0.8640
# Time cost: 0.00021535302851474555ms
# Accuracy of the model on the test images: 79.50%
# Epoch [33/100], Loss: 0.0192
# AUC: 0.7579
# Dice Similarity Coefficient: 0.8721
# Time cost: 0.00021489691528941656ms
# Accuracy of the model on the test images: 77.72%
# Epoch [34/100], Loss: 0.0101
# AUC: 0.7376
# Dice Similarity Coefficient: 0.8586
# Time cost: 0.00021432504676334915ms
# Accuracy of the model on the test images: 79.04%
# Epoch [35/100], Loss: 0.0400
# AUC: 0.7591
# Dice Similarity Coefficient: 0.8676
# Time cost: 0.00021999761660582587ms
# Accuracy of the model on the test images: 78.80%
# Epoch [36/100], Loss: 0.0323
# AUC: 0.7426
# Dice Similarity Coefficient: 0.8708
# Time cost: 0.00021759476060501372ms
# Accuracy of the model on the test images: 79.74%
# Epoch [37/100], Loss: 0.0258
# AUC: 0.7726
# Dice Similarity Coefficient: 0.8730
# Time cost: 0.00021511946419019108ms
# Accuracy of the model on the test images: 79.97%
# Epoch [38/100], Loss: 0.0050
# AUC: 0.7586
# Dice Similarity Coefficient: 0.8756
# Time cost: 0.0002139004861925763ms
# Accuracy of the model on the test images: 81.99%
# Epoch [39/100], Loss: 0.0029
# AUC: 0.7525
# Dice Similarity Coefficient: 0.8894
# Time cost: 0.00021617246402271483ms
# Accuracy of the model on the test images: 81.29%
# Epoch [40/100], Loss: 0.0263
# AUC: 0.7570
# Dice Similarity Coefficient: 0.8854
# Time cost: 0.00021521897640840653ms
# Accuracy of the model on the test images: 77.80%
# Epoch [41/100], Loss: 0.0214
# AUC: 0.7681
# Dice Similarity Coefficient: 0.8576
# Time cost: 0.00021895843272855156ms
# Accuracy of the model on the test images: 75.54%
# Epoch [42/100], Loss: 0.0318
# AUC: 0.7556
# Dice Similarity Coefficient: 0.8392
# Time cost: 0.00021581548961140535ms
# Accuracy of the model on the test images: 78.73%
# Epoch [43/100], Loss: 0.1110
# AUC: 0.7554
# Dice Similarity Coefficient: 0.8650
# Time cost: 0.00021796387065269095ms
# Accuracy of the model on the test images: 80.59%
# Epoch [44/100], Loss: 0.0347
# AUC: 0.7612
# Dice Similarity Coefficient: 0.8804
# Time cost: 0.00021673835808164735ms
# Accuracy of the model on the test images: 79.35%
# Epoch [45/100], Loss: 0.0067
# AUC: 0.7665
# Dice Similarity Coefficient: 0.8697
# Time cost: 0.0002146000589536519ms
# Accuracy of the model on the test images: 80.51%
# Epoch [46/100], Loss: 0.0243
# AUC: 0.7763
# Dice Similarity Coefficient: 0.8785
# Time cost: 0.00022215290562473616ms
# Accuracy of the model on the test images: 80.75%
# Epoch [47/100], Loss: 0.0263
# AUC: 0.7546
# Dice Similarity Coefficient: 0.8827
# Time cost: 0.00021852827109483975ms
# Accuracy of the model on the test images: 78.88%
# Epoch [48/100], Loss: 0.0193
# AUC: 0.7639
# Dice Similarity Coefficient: 0.8701
# Time cost: 0.0002227096512808684ms
# Accuracy of the model on the test images: 79.74%
# Epoch [49/100], Loss: 0.0323
# AUC: 0.7593
# Dice Similarity Coefficient: 0.8748
# Time cost: 0.00022163312698400106ms
# Accuracy of the model on the test images: 79.35%
# Epoch [50/100], Loss: 0.0155
# AUC: 0.7483
# Dice Similarity Coefficient: 0.8716
# Time cost: 0.0002209652935795795ms
# Accuracy of the model on the test images: 79.74%
# Epoch [51/100], Loss: 0.0217
# AUC: 0.7491
# Dice Similarity Coefficient: 0.8741
# Time cost: 0.00021860985991165055ms
# Accuracy of the model on the test images: 80.75%
# Epoch [52/100], Loss: 0.0112
# AUC: 0.7417
# Dice Similarity Coefficient: 0.8830
# Time cost: 0.00023476537915067739ms
# Accuracy of the model on the test images: 79.66%
# Epoch [53/100], Loss: 0.0239
# AUC: 0.7354
# Dice Similarity Coefficient: 0.8745
# Time cost: 0.00021683282934321774ms
# Accuracy of the model on the test images: 80.20%
# Epoch [54/100], Loss: 0.0216
# AUC: 0.7513
# Dice Similarity Coefficient: 0.8777
# Time cost: 0.00022308268207260287ms
# Accuracy of the model on the test images: 80.05%
# Epoch [55/100], Loss: 0.0054
# AUC: 0.7579
# Dice Similarity Coefficient: 0.8741
# Time cost: 0.00021663044426902347ms
# Accuracy of the model on the test images: 81.06%
# Epoch [56/100], Loss: 0.0035
# AUC: 0.7424
# Dice Similarity Coefficient: 0.8836
# Time cost: 0.0002210743276047912ms
# Accuracy of the model on the test images: 76.55%
# Epoch [57/100], Loss: 0.0123
# AUC: 0.7725
# Dice Similarity Coefficient: 0.8475
# Time cost: 0.00022060197129693924ms
# Accuracy of the model on the test images: 81.68%
# Epoch [58/100], Loss: 0.0358
# AUC: 0.7609
# Dice Similarity Coefficient: 0.8875
# Time cost: 0.0002161913209346093ms
# Accuracy of the model on the test images: 80.20%
# Epoch [59/100], Loss: 0.0330
# AUC: 0.7535
# Dice Similarity Coefficient: 0.8771
# Time cost: 0.00021645923844518938ms
# Accuracy of the model on the test images: 78.49%
# Epoch [60/100], Loss: 0.0141
# AUC: 0.7543
# Dice Similarity Coefficient: 0.8625
# Time cost: 0.0002155326359329881ms
# Accuracy of the model on the test images: 81.13%
# Epoch [61/100], Loss: 0.0055
# AUC: 0.7489
# Dice Similarity Coefficient: 0.8829
# Time cost: 0.00021922747045171942ms
# Accuracy of the model on the test images: 80.43%
# Epoch [62/100], Loss: 0.0037
# AUC: 0.7496
# Dice Similarity Coefficient: 0.8792
# Time cost: 0.00021530803330913593ms
# Accuracy of the model on the test images: 79.04%
# Epoch [63/100], Loss: 0.0473
# AUC: 0.7521
# Dice Similarity Coefficient: 0.8684
# Time cost: 0.00021297239006359128ms
# Accuracy of the model on the test images: 78.11%
# Epoch [64/100], Loss: 0.0157
# AUC: 0.7695
# Dice Similarity Coefficient: 0.8600
# Time cost: 0.00021712184419086787ms
# Accuracy of the model on the test images: 79.89%
# Epoch [65/100], Loss: 0.0173
# AUC: 0.7557
# Dice Similarity Coefficient: 0.8752
# Time cost: 0.00021774393558128793ms
# Accuracy of the model on the test images: 81.13%
# Epoch [66/100], Loss: 0.0082
# AUC: 0.7625
# Dice Similarity Coefficient: 0.8840
# Time cost: 0.00021348227349313423ms
# Accuracy of the model on the test images: 79.74%
# Epoch [67/100], Loss: 0.0355
# AUC: 0.7658
# Dice Similarity Coefficient: 0.8729
# Time cost: 0.00021527573384618796ms
# Accuracy of the model on the test images: 80.20%
# Epoch [68/100], Loss: 0.0112
# AUC: 0.7356
# Dice Similarity Coefficient: 0.8778
# Time cost: 0.00021540978595252698ms
# Accuracy of the model on the test images: 78.42%
# Epoch [69/100], Loss: 0.0105
# AUC: 0.7582
# Dice Similarity Coefficient: 0.8614
# Time cost: 0.00021454610204733995ms
# Accuracy of the model on the test images: 80.98%
# Epoch [70/100], Loss: 0.0025
# AUC: 0.7586
# Dice Similarity Coefficient: 0.8814
# Time cost: 0.00021674582616556596ms
# Accuracy of the model on the test images: 79.27%
# Epoch [71/100], Loss: 0.0045
# AUC: 0.7631
# Dice Similarity Coefficient: 0.8675
# Time cost: 0.00021483997114953718ms
# Accuracy of the model on the test images: 79.97%
# Epoch [72/100], Loss: 0.0080
# AUC: 0.7516
# Dice Similarity Coefficient: 0.8754
# Time cost: 0.00021547979923926394ms
# Accuracy of the model on the test images: 80.98%
# Epoch [73/100], Loss: 0.0299
# AUC: 0.7599
# Dice Similarity Coefficient: 0.8808
# Time cost: 0.0002194190268042317ms
# Accuracy of the model on the test images: 79.50%
# Epoch [74/100], Loss: 0.0272
# AUC: 0.7469
# Dice Similarity Coefficient: 0.8723
# Time cost: 0.0002170053420817376ms
# Accuracy of the model on the test images: 79.11%
# Epoch [75/100], Loss: 0.0089
# AUC: 0.7589
# Dice Similarity Coefficient: 0.8654
# Time cost: 0.00022406156117223442ms
# Accuracy of the model on the test images: 81.37%
# Epoch [76/100], Loss: 0.0106
# AUC: 0.7562
# Dice Similarity Coefficient: 0.8863
# Time cost: 0.0002151596051412536ms
# Accuracy of the model on the test images: 80.90%
# Epoch [77/100], Loss: 0.0062
# AUC: 0.7564
# Dice Similarity Coefficient: 0.8821
# Time cost: 0.00021489075412018372ms
# Accuracy of the model on the test images: 80.98%
# Epoch [78/100], Loss: 0.0012
# AUC: 0.7591
# Dice Similarity Coefficient: 0.8814
# Time cost: 0.00022124721374750696ms
# Accuracy of the model on the test images: 80.90%
# Epoch [79/100], Loss: 0.0004
# AUC: 0.7555
# Dice Similarity Coefficient: 0.8806
# Time cost: 0.00022430016645343394ms
# Accuracy of the model on the test images: 80.98%
# Epoch [80/100], Loss: 0.0001
# AUC: 0.7548
# Dice Similarity Coefficient: 0.8825
# Time cost: 0.0002302596974204832ms
# Accuracy of the model on the test images: 79.35%
# Epoch [81/100], Loss: 0.0018
# AUC: 0.7578
# Dice Similarity Coefficient: 0.8683
# Time cost: 0.0002163438565486469ms
# Accuracy of the model on the test images: 78.96%
# Epoch [82/100], Loss: 0.0492
# AUC: 0.7507
# Dice Similarity Coefficient: 0.8666
# Time cost: 0.000219782349086872ms
# Accuracy of the model on the test images: 80.05%
# Epoch [83/100], Loss: 0.0190
# AUC: 0.7516
# Dice Similarity Coefficient: 0.8754
# Time cost: 0.0002224788874877834ms
# Accuracy of the model on the test images: 79.50%
# Epoch [84/100], Loss: 0.0161
# AUC: 0.7411
# Dice Similarity Coefficient: 0.8728
# Time cost: 0.0002242021478520022ms
# Accuracy of the model on the test images: 79.27%
# Epoch [85/100], Loss: 0.0133
# AUC: 0.7511
# Dice Similarity Coefficient: 0.8705
# Time cost: 0.00021888300508097363ms
# Accuracy of the model on the test images: 80.20%
# Epoch [86/100], Loss: 0.0134
# AUC: 0.7337
# Dice Similarity Coefficient: 0.8783
# Time cost: 0.00021694839794185821ms
# Accuracy of the model on the test images: 81.13%
# Epoch [87/100], Loss: 0.0286
# AUC: 0.7720
# Dice Similarity Coefficient: 0.8832
# Time cost: 0.00021660486608160223ms
# Accuracy of the model on the test images: 80.98%
# Epoch [88/100], Loss: 0.0047
# AUC: 0.7414
# Dice Similarity Coefficient: 0.8839
# Time cost: 0.00022761972975525522ms
# Accuracy of the model on the test images: 80.36%
# Epoch [89/100], Loss: 0.0146
# AUC: 0.7670
# Dice Similarity Coefficient: 0.8777
# Time cost: 0.00021316954747904252ms
# Accuracy of the model on the test images: 79.19%
# Epoch [90/100], Loss: 0.0160
# AUC: 0.7500
# Dice Similarity Coefficient: 0.8682
# Time cost: 0.0002268499570053447ms
# Accuracy of the model on the test images: 79.43%
# Epoch [91/100], Loss: 0.0124
# AUC: 0.7497
# Dice Similarity Coefficient: 0.8717
# Time cost: 0.0002170611660090292ms
# Accuracy of the model on the test images: 80.05%
# Epoch [92/100], Loss: 0.0076
# AUC: 0.7397
# Dice Similarity Coefficient: 0.8784
# Time cost: 0.00021736437021612468ms
# Accuracy of the model on the test images: 78.57%
# Epoch [93/100], Loss: 0.0089
# AUC: 0.7532
# Dice Similarity Coefficient: 0.8640
# Time cost: 0.0002245156206744858ms
# Accuracy of the model on the test images: 80.51%
# Epoch [94/100], Loss: 0.0057
# AUC: 0.7550
# Dice Similarity Coefficient: 0.8796
# Time cost: 0.00022043730004653393ms
# Accuracy of the model on the test images: 80.59%
# Epoch [95/100], Loss: 0.0069
# AUC: 0.7583
# Dice Similarity Coefficient: 0.8789
# Time cost: 0.0002220330428778425ms
# Accuracy of the model on the test images: 81.52%
# Epoch [96/100], Loss: 0.0008
# AUC: 0.7563
# Dice Similarity Coefficient: 0.8868
# Time cost: 0.00022617222838973103ms
# Accuracy of the model on the test images: 79.89%
# Epoch [97/100], Loss: 0.0006
# AUC: 0.7483
# Dice Similarity Coefficient: 0.8755
# Time cost: 0.00022390809204770703ms
# Accuracy of the model on the test images: 80.20%
# Epoch [98/100], Loss: 0.0007
# AUC: 0.7523
# Dice Similarity Coefficient: 0.8763
# Time cost: 0.00022116693184538193ms
# Accuracy of the model on the test images: 79.19%
# Epoch [99/100], Loss: 0.0065
# AUC: 0.7364
# Dice Similarity Coefficient: 0.8695
# Time cost: 0.00021942798850493406ms
# Accuracy of the model on the test images: 80.12%
# Epoch [100/100], Loss: 0.0361
# AUC: 0.7569
# Dice Similarity Coefficient: 0.8746
